# %% [markdown]
# # Assignment : 7

# %% [markdown]
# ## 12/1025 sunday

# %%
import matplotlib.pyplot as plt

# Data
data = {
    'Country': ['USA', 'China', 'India', 'Germany', 'Brazil', 'Japan', 'Russia', 'Canada', 'Australia', 'Mexico'],
    'GDP per Capita (USD)': [59850, 10660, 1800, 46100, 10600, 38900, 10750, 41300, 51000, 9500],
    'Life Expectancy (years)': [78.54, 76.91, 69.42, 81.13, 75.88, 84.6, 73.34, 82.2, 82.5, 77.03],
    'Population (millions)': [331, 1393, 1380, 83, 213, 126, 145, 38, 26, 128],
    'Color Grading': [60850, 10660, 1800, 46100, 10600, 38900, 10750, 41300, 51000, 9500]
}


plt.figure(figsize=(8, 4))
plt.scatter(
    data['GDP per Capita (USD)'], 
    data['Life Expectancy (years)'], 
    c=data['Color Grading'], 
    cmap='cividis', 
    s=100, 
     alpha=0.8,  
   edgecolors='black'
)


plt.xlabel('GDP per Capita (USD)')
plt.ylabel('Life Expectancy (years)')
plt.title('Life Expectancy vs GDP per Capita')
plt.colorbar(label='GDP per Capita (USD)')

plt.grid(True)
plt.show()
